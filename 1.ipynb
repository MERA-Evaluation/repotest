# %%
import repotest
# Out:
# DEFAULT_CACHE_FOLDER=/Users/ivanlopatin/.cache/repotest/repos

# %%
from repotest.core.docker.golang import GoLangDockerRepo

# %%
repo = GoLangDockerRepo(
        repo="TheAlgorithms/Go",
        base_commit="5ba447ec5ff3d1213de65b92e726ee74c5d5cc19",
        cache_mode="download",
        image_name="golang:latest"
    )
repo.clean()

# %%
dct_build = repo.build_env()

# %%
dct_build
# Out:
# {'stdout': '',
#  'stderr': '',
#  'std': '',
#  'returncode': 0,
#  'parser': {'tests': [],
#   'summary': {'total': 0,
#    'passed': 0,
#    'failed': 0,
#    'skipped': 0,
#    'errors': 0,
#    'collected': 0},
#   'status': 'unknown',
#   'packages': {}},
#  'report': {'tests': [],
#   'summary': {'total': 0,
#    'passed': 0,
#    'failed': 0,
#    'skipped': 0,
#    'errors': 0,
#    'collected': 0},
#   'status': 'unknown',
#   'packages': {}},
#  'time': 6.615630149841309,
#  'run_id': '27f520ab'}

# %%
dct_test = repo.run_test()

# %%
dct_test
# Out:
# {'stdout': '',
#  'stderr': '',
#  'std': '',
#  'returncode': 0,
#  'parser': {'tests': [{'name': 'TestLFU',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLFU\n', '--- PASS: TestLFU (0.00s)\n'],
#     'message': '=== RUN   TestLFU\n--- PASS: TestLFU (0.00s)\n',
#     'details': '=== RUN   TestLFU\n--- PASS: TestLFU (0.00s)\n'},
#    {'name': 'TestLFU/Test_1:_Put_number_and_Get_is_correct',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLFU/Test_1:_Put_number_and_Get_is_correct\n',
#      '--- PASS: TestLFU/Test_1:_Put_number_and_Get_is_correct (0.00s)\n'],
#     'message': '=== RUN   TestLFU/Test_1:_Put_number_and_Get_is_correct\n--- PASS: TestLFU/Test_1:_Put_number_and_Get_is_correct (0.00s)\n',
#     'details': '=== RUN   TestLFU/Test_1:_Put_number_and_Get_is_correct\n--- PASS: TestLFU/Test_1:_Put_number_and_Get_is_correct (0.00s)\n'},
#    {'name': 'TestLFU/Test_2:_Get_data_not_stored_in_cache_should_return_nil',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLFU/Test_2:_Get_data_not_stored_in_cache_should_return_nil\n',
#      '--- PASS: TestLFU/Test_2:_Get_data_not_stored_in_cache_should_return_nil (0.00s)\n'],
#     'message': '=== RUN   TestLFU/Test_2:_Get_data_not_stored_in_cache_should_return_nil\n--- PASS: TestLFU/Test_2:_Get_data_not_stored_in_cache_should_return_nil (0.00s)\n',
#     'details': '=== RUN   TestLFU/Test_2:_Get_data_not_stored_in_cache_should_return_nil\n--- PASS: TestLFU/Test_2:_Get_data_not_stored_in_cache_should_return_nil (0.00s)\n'},
#    {'name': 'TestLFU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLFU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil\n',
#      '--- PASS: TestLFU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil (0.00s)\n'],
#     'message': '=== RUN   TestLFU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil\n--- PASS: TestLFU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil (0.00s)\n',
#     'details': '=== RUN   TestLFU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil\n--- PASS: TestLFU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil (0.00s)\n'},
#    {'name': 'TestLFU/test_4:_Put_key_over_capacity_but_recent_key_exists',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLFU/test_4:_Put_key_over_capacity_but_recent_key_exists\n',
#      '--- PASS: TestLFU/test_4:_Put_key_over_capacity_but_recent_key_exists (0.00s)\n'],
#     'message': '=== RUN   TestLFU/test_4:_Put_key_over_capacity_but_recent_key_exists\n--- PASS: TestLFU/test_4:_Put_key_over_capacity_but_recent_key_exists (0.00s)\n',
#     'details': '=== RUN   TestLFU/test_4:_Put_key_over_capacity_but_recent_key_exists\n--- PASS: TestLFU/test_4:_Put_key_over_capacity_but_recent_key_exists (0.00s)\n'},
#    {'name': 'TestLRU',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLRU\n', '--- PASS: TestLRU (0.00s)\n'],
#     'message': '=== RUN   TestLRU\n--- PASS: TestLRU (0.00s)\n',
#     'details': '=== RUN   TestLRU\n--- PASS: TestLRU (0.00s)\n'},
#    {'name': 'TestLRU/Test_1:_Put_number_and_Get_is_correct',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLRU/Test_1:_Put_number_and_Get_is_correct\n',
#      '--- PASS: TestLRU/Test_1:_Put_number_and_Get_is_correct (0.00s)\n'],
#     'message': '=== RUN   TestLRU/Test_1:_Put_number_and_Get_is_correct\n--- PASS: TestLRU/Test_1:_Put_number_and_Get_is_correct (0.00s)\n',
#     'details': '=== RUN   TestLRU/Test_1:_Put_number_and_Get_is_correct\n--- PASS: TestLRU/Test_1:_Put_number_and_Get_is_correct (0.00s)\n'},
#    {'name': 'TestLRU/Test_2:_Get_data_not_stored_in_cache_should_return_nil',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLRU/Test_2:_Get_data_not_stored_in_cache_should_return_nil\n',
#      '--- PASS: TestLRU/Test_2:_Get_data_not_stored_in_cache_should_return_nil (0.00s)\n'],
#     'message': '=== RUN   TestLRU/Test_2:_Get_data_not_stored_in_cache_should_return_nil\n--- PASS: TestLRU/Test_2:_Get_data_not_stored_in_cache_should_return_nil (0.00s)\n',
#     'details': '=== RUN   TestLRU/Test_2:_Get_data_not_stored_in_cache_should_return_nil\n--- PASS: TestLRU/Test_2:_Get_data_not_stored_in_cache_should_return_nil (0.00s)\n'},
#    {'name': 'TestLRU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLRU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil\n',
#      '--- PASS: TestLRU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil (0.00s)\n'],
#     'message': '=== RUN   TestLRU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil\n--- PASS: TestLRU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil (0.00s)\n',
#     'details': '=== RUN   TestLRU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil\n--- PASS: TestLRU/Test_3:_Put_data_over_capacity_and_Get_should_return_nil (0.00s)\n'},
#    {'name': 'TestLRU/test_4:_Put_key_over_capacity_but_recent_key_exists',
#     'classname': 'github.com/TheAlgorithms/Go/cache',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLRU/test_4:_Put_key_over_capacity_but_recent_key_exists\n',
#      '--- PASS: TestLRU/test_4:_Put_key_over_capacity_but_recent_key_exists (0.00s)\n'],
#     'message': '=== RUN   TestLRU/test_4:_Put_key_over_capacity_but_recent_key_exists\n--- PASS: TestLRU/test_4:_Put_key_over_capacity_but_recent_key_exists (0.00s)\n',
#     'details': '=== RUN   TestLRU/test_4:_Put_key_over_capacity_but_recent_key_exists\n--- PASS: TestLRU/test_4:_Put_key_over_capacity_but_recent_key_exists (0.00s)\n'},
#    {'name': 'TestCalculateCRC8',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8\n',
#      '--- PASS: TestCalculateCRC8 (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8\n--- PASS: TestCalculateCRC8 (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8\n--- PASS: TestCalculateCRC8 (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8\n',
#      '244\n',
#      '--- PASS: TestCalculateCRC8/CRC-8 (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8\n244\n--- PASS: TestCalculateCRC8/CRC-8 (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8\n244\n--- PASS: TestCalculateCRC8/CRC-8 (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/CDMA2000',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/CDMA2000\n',
#      '218\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/CDMA2000 (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/CDMA2000\n218\n--- PASS: TestCalculateCRC8/CRC-8/CDMA2000 (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/CDMA2000\n218\n--- PASS: TestCalculateCRC8/CRC-8/CDMA2000 (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/DARC',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/DARC\n',
#      '21\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/DARC (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/DARC\n21\n--- PASS: TestCalculateCRC8/CRC-8/DARC (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/DARC\n21\n--- PASS: TestCalculateCRC8/CRC-8/DARC (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/DVB-S2',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/DVB-S2\n',
#      '188\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/DVB-S2 (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/DVB-S2\n188\n--- PASS: TestCalculateCRC8/CRC-8/DVB-S2 (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/DVB-S2\n188\n--- PASS: TestCalculateCRC8/CRC-8/DVB-S2 (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/EBU',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/EBU\n',
#      '151\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/EBU (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/EBU\n151\n--- PASS: TestCalculateCRC8/CRC-8/EBU (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/EBU\n151\n--- PASS: TestCalculateCRC8/CRC-8/EBU (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/I-CODE',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/I-CODE\n',
#      '126\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/I-CODE (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/I-CODE\n126\n--- PASS: TestCalculateCRC8/CRC-8/I-CODE (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/I-CODE\n126\n--- PASS: TestCalculateCRC8/CRC-8/I-CODE (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/ITU',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/ITU\n',
#      '161\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/ITU (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/ITU\n161\n--- PASS: TestCalculateCRC8/CRC-8/ITU (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/ITU\n161\n--- PASS: TestCalculateCRC8/CRC-8/ITU (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/MAXIM',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/MAXIM\n',
#      '161\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/MAXIM (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/MAXIM\n161\n--- PASS: TestCalculateCRC8/CRC-8/MAXIM (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/MAXIM\n161\n--- PASS: TestCalculateCRC8/CRC-8/MAXIM (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/ROHC',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/ROHC\n',
#      '208\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/ROHC (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/ROHC\n208\n--- PASS: TestCalculateCRC8/CRC-8/ROHC (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/ROHC\n208\n--- PASS: TestCalculateCRC8/CRC-8/ROHC (0.00s)\n'},
#    {'name': 'TestCalculateCRC8/CRC-8/WCDMA',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestCalculateCRC8/CRC-8/WCDMA\n',
#      '37\n',
#      '--- PASS: TestCalculateCRC8/CRC-8/WCDMA (0.00s)\n'],
#     'message': '=== RUN   TestCalculateCRC8/CRC-8/WCDMA\n37\n--- PASS: TestCalculateCRC8/CRC-8/WCDMA (0.00s)\n',
#     'details': '=== RUN   TestCalculateCRC8/CRC-8/WCDMA\n37\n--- PASS: TestCalculateCRC8/CRC-8/WCDMA (0.00s)\n'},
#    {'name': 'TestLuhn',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLuhn\n', '--- PASS: TestLuhn (0.00s)\n'],
#     'message': '=== RUN   TestLuhn\n--- PASS: TestLuhn (0.00s)\n',
#     'details': '=== RUN   TestLuhn\n--- PASS: TestLuhn (0.00s)\n'},
#    {'name': 'TestLuhn/check_4242424242424242',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLuhn/check_4242424242424242\n',
#      '--- PASS: TestLuhn/check_4242424242424242 (0.00s)\n'],
#     'message': '=== RUN   TestLuhn/check_4242424242424242\n--- PASS: TestLuhn/check_4242424242424242 (0.00s)\n',
#     'details': '=== RUN   TestLuhn/check_4242424242424242\n--- PASS: TestLuhn/check_4242424242424242 (0.00s)\n'},
#    {'name': 'TestLuhn/check_6200000000000005',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLuhn/check_6200000000000005\n',
#      '--- PASS: TestLuhn/check_6200000000000005 (0.00s)\n'],
#     'message': '=== RUN   TestLuhn/check_6200000000000005\n--- PASS: TestLuhn/check_6200000000000005 (0.00s)\n',
#     'details': '=== RUN   TestLuhn/check_6200000000000005\n--- PASS: TestLuhn/check_6200000000000005 (0.00s)\n'},
#    {'name': 'TestLuhn/check_5534200028533164',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLuhn/check_5534200028533164\n',
#      '--- PASS: TestLuhn/check_5534200028533164 (0.00s)\n'],
#     'message': '=== RUN   TestLuhn/check_5534200028533164\n--- PASS: TestLuhn/check_5534200028533164 (0.00s)\n',
#     'details': '=== RUN   TestLuhn/check_5534200028533164\n--- PASS: TestLuhn/check_5534200028533164 (0.00s)\n'},
#    {'name': 'TestLuhn/check_36227206271667',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLuhn/check_36227206271667\n',
#      '--- PASS: TestLuhn/check_36227206271667 (0.00s)\n'],
#     'message': '=== RUN   TestLuhn/check_36227206271667\n--- PASS: TestLuhn/check_36227206271667 (0.00s)\n',
#     'details': '=== RUN   TestLuhn/check_36227206271667\n--- PASS: TestLuhn/check_36227206271667 (0.00s)\n'},
#    {'name': 'TestLuhn/check_471629309440',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLuhn/check_471629309440\n',
#      '--- PASS: TestLuhn/check_471629309440 (0.00s)\n'],
#     'message': '=== RUN   TestLuhn/check_471629309440\n--- PASS: TestLuhn/check_471629309440 (0.00s)\n',
#     'details': '=== RUN   TestLuhn/check_471629309440\n--- PASS: TestLuhn/check_471629309440 (0.00s)\n'},
#    {'name': 'TestLuhn/check_1111',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLuhn/check_1111\n',
#      '--- PASS: TestLuhn/check_1111 (0.00s)\n'],
#     'message': '=== RUN   TestLuhn/check_1111\n--- PASS: TestLuhn/check_1111 (0.00s)\n',
#     'details': '=== RUN   TestLuhn/check_1111\n--- PASS: TestLuhn/check_1111 (0.00s)\n'},
#    {'name': 'TestLuhn/check_12345674',
#     'classname': 'github.com/TheAlgorithms/Go/checksum',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestLuhn/check_12345674\n',
#      '--- PASS: TestLuhn/check_12345674 (0.00s)\n'],
#     'message': '=== RUN   TestLuhn/check_12345674\n--- PASS: TestLuhn/check_12345674 (0.00s)\n',
#     'details': '=== RUN   TestLuhn/check_12345674\n--- PASS: TestLuhn/check_12345674 (0.00s)\n'},
#    {'name': 'TestEncrypt',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt\n', '--- PASS: TestEncrypt (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt\n--- PASS: TestEncrypt (0.00s)\n',
#     'details': '=== RUN   TestEncrypt\n--- PASS: TestEncrypt (0.00s)\n'},
#    {'name': "TestEncrypt/Basic_caesar_encryption_with_letter_'a'",
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ["=== RUN   TestEncrypt/Basic_caesar_encryption_with_letter_'a'\n",
#      "--- PASS: TestEncrypt/Basic_caesar_encryption_with_letter_'a' (0.00s)\n"],
#     'message': "=== RUN   TestEncrypt/Basic_caesar_encryption_with_letter_'a'\n--- PASS: TestEncrypt/Basic_caesar_encryption_with_letter_'a' (0.00s)\n",
#     'details': "=== RUN   TestEncrypt/Basic_caesar_encryption_with_letter_'a'\n--- PASS: TestEncrypt/Basic_caesar_encryption_with_letter_'a' (0.00s)\n"},
#    {'name': "TestEncrypt/Basic_caesar_encryption_wrap_around_alphabet_on_letter_'z'",
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ["=== RUN   TestEncrypt/Basic_caesar_encryption_wrap_around_alphabet_on_letter_'z'\n",
#      "--- PASS: TestEncrypt/Basic_caesar_encryption_wrap_around_alphabet_on_letter_'z' (0.00s)\n"],
#     'message': "=== RUN   TestEncrypt/Basic_caesar_encryption_wrap_around_alphabet_on_letter_'z'\n--- PASS: TestEncrypt/Basic_caesar_encryption_wrap_around_alphabet_on_letter_'z' (0.00s)\n",
#     'details': "=== RUN   TestEncrypt/Basic_caesar_encryption_wrap_around_alphabet_on_letter_'z'\n--- PASS: TestEncrypt/Basic_caesar_encryption_wrap_around_alphabet_on_letter_'z' (0.00s)\n"},
#    {'name': 'TestEncrypt/Encrypt_a_simple_string_with_caesar_encryiption',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_a_simple_string_with_caesar_encryiption\n',
#      '--- PASS: TestEncrypt/Encrypt_a_simple_string_with_caesar_encryiption (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_a_simple_string_with_caesar_encryiption\n--- PASS: TestEncrypt/Encrypt_a_simple_string_with_caesar_encryiption (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_a_simple_string_with_caesar_encryiption\n--- PASS: TestEncrypt/Encrypt_a_simple_string_with_caesar_encryiption (0.00s)\n'},
#    {'name': 'TestEncrypt/Encrypt_a_simple_string_with_key_13',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_a_simple_string_with_key_13\n',
#      '--- PASS: TestEncrypt/Encrypt_a_simple_string_with_key_13 (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_a_simple_string_with_key_13\n--- PASS: TestEncrypt/Encrypt_a_simple_string_with_key_13 (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_a_simple_string_with_key_13\n--- PASS: TestEncrypt/Encrypt_a_simple_string_with_key_13 (0.00s)\n'},
#    {'name': 'TestEncrypt/Encrypt_a_simple_string_with_key_-13',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_a_simple_string_with_key_-13\n',
#      '--- PASS: TestEncrypt/Encrypt_a_simple_string_with_key_-13 (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_a_simple_string_with_key_-13\n--- PASS: TestEncrypt/Encrypt_a_simple_string_with_key_-13 (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_a_simple_string_with_key_-13\n--- PASS: TestEncrypt/Encrypt_a_simple_string_with_key_-13 (0.00s)\n'},
#    {'name': 'TestEncrypt/With_key_of_26_output_should_be_the_same_as_the_input',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/With_key_of_26_output_should_be_the_same_as_the_input\n',
#      '--- PASS: TestEncrypt/With_key_of_26_output_should_be_the_same_as_the_input (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/With_key_of_26_output_should_be_the_same_as_the_input\n--- PASS: TestEncrypt/With_key_of_26_output_should_be_the_same_as_the_input (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/With_key_of_26_output_should_be_the_same_as_the_input\n--- PASS: TestEncrypt/With_key_of_26_output_should_be_the_same_as_the_input (0.00s)\n'},
#    {'name': 'TestEncrypt/Encrypt_sentence_with_key_10',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_sentence_with_key_10\n',
#      '--- PASS: TestEncrypt/Encrypt_sentence_with_key_10 (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_sentence_with_key_10\n--- PASS: TestEncrypt/Encrypt_sentence_with_key_10 (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_sentence_with_key_10\n--- PASS: TestEncrypt/Encrypt_sentence_with_key_10 (0.00s)\n'},
#    {'name': 'TestEncrypt/Encrypt_sentence_with_key_10#01',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_sentence_with_key_10#01\n',
#      '--- PASS: TestEncrypt/Encrypt_sentence_with_key_10#01 (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_sentence_with_key_10#01\n--- PASS: TestEncrypt/Encrypt_sentence_with_key_10#01 (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_sentence_with_key_10#01\n--- PASS: TestEncrypt/Encrypt_sentence_with_key_10#01 (0.00s)\n'},
#    {'name': 'TestDecrypt',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt\n', '--- PASS: TestDecrypt (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt\n--- PASS: TestDecrypt (0.00s)\n',
#     'details': '=== RUN   TestDecrypt\n--- PASS: TestDecrypt (0.00s)\n'},
#    {'name': "TestDecrypt/Basic_caesar_decryption_with_letter_'a'",
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ["=== RUN   TestDecrypt/Basic_caesar_decryption_with_letter_'a'\n",
#      "--- PASS: TestDecrypt/Basic_caesar_decryption_with_letter_'a' (0.00s)\n"],
#     'message': "=== RUN   TestDecrypt/Basic_caesar_decryption_with_letter_'a'\n--- PASS: TestDecrypt/Basic_caesar_decryption_with_letter_'a' (0.00s)\n",
#     'details': "=== RUN   TestDecrypt/Basic_caesar_decryption_with_letter_'a'\n--- PASS: TestDecrypt/Basic_caesar_decryption_with_letter_'a' (0.00s)\n"},
#    {'name': "TestDecrypt/Basic_caesar_decryption_wrap_around_alphabet_on_letter_'z'",
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ["=== RUN   TestDecrypt/Basic_caesar_decryption_wrap_around_alphabet_on_letter_'z'\n",
#      "--- PASS: TestDecrypt/Basic_caesar_decryption_wrap_around_alphabet_on_letter_'z' (0.00s)\n"],
#     'message': "=== RUN   TestDecrypt/Basic_caesar_decryption_wrap_around_alphabet_on_letter_'z'\n--- PASS: TestDecrypt/Basic_caesar_decryption_wrap_around_alphabet_on_letter_'z' (0.00s)\n",
#     'details': "=== RUN   TestDecrypt/Basic_caesar_decryption_wrap_around_alphabet_on_letter_'z'\n--- PASS: TestDecrypt/Basic_caesar_decryption_wrap_around_alphabet_on_letter_'z' (0.00s)\n"},
#    {'name': 'TestDecrypt/Decrypt_a_simple_string_with_caesar_encryiption',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/Decrypt_a_simple_string_with_caesar_encryiption\n',
#      '--- PASS: TestDecrypt/Decrypt_a_simple_string_with_caesar_encryiption (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/Decrypt_a_simple_string_with_caesar_encryiption\n--- PASS: TestDecrypt/Decrypt_a_simple_string_with_caesar_encryiption (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/Decrypt_a_simple_string_with_caesar_encryiption\n--- PASS: TestDecrypt/Decrypt_a_simple_string_with_caesar_encryiption (0.00s)\n'},
#    {'name': 'TestDecrypt/Decrypt_a_simple_string_with_key_13',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/Decrypt_a_simple_string_with_key_13\n',
#      '--- PASS: TestDecrypt/Decrypt_a_simple_string_with_key_13 (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/Decrypt_a_simple_string_with_key_13\n--- PASS: TestDecrypt/Decrypt_a_simple_string_with_key_13 (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/Decrypt_a_simple_string_with_key_13\n--- PASS: TestDecrypt/Decrypt_a_simple_string_with_key_13 (0.00s)\n'},
#    {'name': 'TestDecrypt/Decrypt_a_simple_string_with_key_-13',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/Decrypt_a_simple_string_with_key_-13\n',
#      '--- PASS: TestDecrypt/Decrypt_a_simple_string_with_key_-13 (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/Decrypt_a_simple_string_with_key_-13\n--- PASS: TestDecrypt/Decrypt_a_simple_string_with_key_-13 (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/Decrypt_a_simple_string_with_key_-13\n--- PASS: TestDecrypt/Decrypt_a_simple_string_with_key_-13 (0.00s)\n'},
#    {'name': 'TestDecrypt/With_key_of_26_output_should_be_the_same_as_the_input',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/With_key_of_26_output_should_be_the_same_as_the_input\n',
#      '--- PASS: TestDecrypt/With_key_of_26_output_should_be_the_same_as_the_input (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/With_key_of_26_output_should_be_the_same_as_the_input\n--- PASS: TestDecrypt/With_key_of_26_output_should_be_the_same_as_the_input (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/With_key_of_26_output_should_be_the_same_as_the_input\n--- PASS: TestDecrypt/With_key_of_26_output_should_be_the_same_as_the_input (0.00s)\n'},
#    {'name': 'TestDecrypt/Decrypt_sentence_with_key_10',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/Decrypt_sentence_with_key_10\n',
#      '--- PASS: TestDecrypt/Decrypt_sentence_with_key_10 (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/Decrypt_sentence_with_key_10\n--- PASS: TestDecrypt/Decrypt_sentence_with_key_10 (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/Decrypt_sentence_with_key_10\n--- PASS: TestDecrypt/Decrypt_sentence_with_key_10 (0.00s)\n'},
#    {'name': 'FuzzCaesar',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   FuzzCaesar\n', '--- PASS: FuzzCaesar (0.00s)\n'],
#     'message': '=== RUN   FuzzCaesar\n--- PASS: FuzzCaesar (0.00s)\n',
#     'details': '=== RUN   FuzzCaesar\n--- PASS: FuzzCaesar (0.00s)\n'},
#    {'name': 'FuzzCaesar/seed#0',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   FuzzCaesar/seed#0\n',
#      '--- PASS: FuzzCaesar/seed#0 (0.00s)\n'],
#     'message': '=== RUN   FuzzCaesar/seed#0\n--- PASS: FuzzCaesar/seed#0 (0.00s)\n',
#     'details': '=== RUN   FuzzCaesar/seed#0\n--- PASS: FuzzCaesar/seed#0 (0.00s)\n'},
#    {'name': 'Example',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   Example\n', '--- PASS: Example (0.00s)\n'],
#     'message': '=== RUN   Example\n--- PASS: Example (0.00s)\n',
#     'details': '=== RUN   Example\n--- PASS: Example (0.00s)\n'},
#    {'name': 'TestDiffieHellmanKeyExchange',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/diffiehellman',
#     'time': 0,
#     'status': 'failed',
#     'output': ['=== RUN   TestDiffieHellmanKeyExchange\n',
#      '--- FAIL: TestDiffieHellmanKeyExchange (0.00s)\n',
#      'panic: runtime error: invalid memory address or nil pointer dereference [recovered, repanicked]\n',
#      '[signal SIGSEGV: segmentation violation code=0x1 addr=0x10 pc=0x126a60]\n',
#      '\n',
#      'goroutine 8 [running]:\n',
#      'testing.tRunner.func1.2({0x15b0c0, 0x2c8bc0})\n',
#      '\t/usr/local/go/src/testing/testing.go:1872 +0x190\n',
#      'testing.tRunner.func1()\n',
#      '\t/usr/local/go/src/testing/testing.go:1875 +0x31c\n',
#      'panic({0x15b0c0?, 0x2c8bc0?})\n',
#      '\t/usr/local/go/src/runtime/panic.go:783 +0x120\n',
#      'github.com/TheAlgorithms/Go/cipher/diffiehellman.TestDiffieHellmanKeyExchange.func2(0x4000003a40)\n',
#      '\t/run_dir/cipher/diffiehellman/diffiehellmankeyexchange_test.go:28 +0x50\n',
#      'testing.tRunner(0x4000003a40, 0x194328)\n',
#      '\t/usr/local/go/src/testing/testing.go:1934 +0xc8\n',
#      'created by testing.(*T).Run in goroutine 6\n',
#      '\t/usr/local/go/src/testing/testing.go:1997 +0x364\n'],
#     'message': '=== RUN   TestDiffieHellmanKeyExchange\n--- FAIL: TestDiffieHellmanKeyExchange (0.00s)\npanic: runtime error: invalid memory address or nil pointer dereference [recovered, repanicked]\n[signal SIGSEGV: segmentation violation code=0x1 addr=0x10 pc=0x126a60]\n\ngoroutine 8 [running]:\ntesting.tRunner.func1.2({0x15b0c0, 0x2c8bc0})\n\t/usr/local/go/src/testing/testing.go:1872 +0x190\ntesting.tRunner.func1()\n\t/usr/local/go/src/testing/testing.go:1875 +0x31c\npanic({0x15b0c0?, 0x2c8bc0?})\n\t/usr/local/go/src/runtime/panic.go:783 +0x120\ngithub.com/TheAlgorithms/Go/cipher/diffiehellman.TestDiffieHellmanKeyExchange.func2(0x4000003a40)\n\t/run_dir/cipher/diffiehellman/diffiehellmankeyexchange_test.go:28 +0x50\ntesting.tRunner(0x4000003a40, 0x194328)\n\t/usr/local/go/src/testing/testing.go:1934 +0xc8\ncreated by testing.(*T).Run in goroutine 6\n\t/usr/local/go/src/testing/testing.go:1997 +0x364\n',
#     'details': '=== RUN   TestDiffieHellmanKeyExchange\n--- FAIL: TestDiffieHellmanKeyExchange (0.00s)\npanic: runtime error: invalid memory address or nil pointer dereference [recovered, repanicked]\n[signal SIGSEGV: segmentation violation code=0x1 addr=0x10 pc=0x126a60]\n\ngoroutine 8 [running]:\ntesting.tRunner.func1.2({0x15b0c0, 0x2c8bc0})\n\t/usr/local/go/src/testing/testing.go:1872 +0x190\ntesting.tRunner.func1()\n\t/usr/local/go/src/testing/testing.go:1875 +0x31c\npanic({0x15b0c0?, 0x2c8bc0?})\n\t/usr/local/go/src/runtime/panic.go:783 +0x120\ngithub.com/TheAlgorithms/Go/cipher/diffiehellman.TestDiffieHellmanKeyExchange.func2(0x4000003a40)\n\t/run_dir/cipher/diffiehellman/diffiehellmankeyexchange_test.go:28 +0x50\ntesting.tRunner(0x4000003a40, 0x194328)\n\t/usr/local/go/src/testing/testing.go:1934 +0xc8\ncreated by testing.(*T).Run in goroutine 6\n\t/usr/local/go/src/testing/testing.go:1997 +0x364\n'},
#    {'name': 'TestDiffieHellmanKeyExchange/Test_1:_modularExponentiation',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/diffiehellman',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDiffieHellmanKeyExchange/Test_1:_modularExponentiation\n',
#      '--- PASS: TestDiffieHellmanKeyExchange/Test_1:_modularExponentiation (0.00s)\n'],
#     'message': '=== RUN   TestDiffieHellmanKeyExchange/Test_1:_modularExponentiation\n--- PASS: TestDiffieHellmanKeyExchange/Test_1:_modularExponentiation (0.00s)\n',
#     'details': '=== RUN   TestDiffieHellmanKeyExchange/Test_1:_modularExponentiation\n--- PASS: TestDiffieHellmanKeyExchange/Test_1:_modularExponentiation (0.00s)\n'},
#    {'name': 'TestDiffieHellmanKeyExchange/Test_2:_Key_Exchange',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/diffiehellman',
#     'time': 0,
#     'status': 'failed',
#     'output': ['=== RUN   TestDiffieHellmanKeyExchange/Test_2:_Key_Exchange\n',
#      '--- FAIL: TestDiffieHellmanKeyExchange/Test_2:_Key_Exchange (0.00s)\n'],
#     'message': '=== RUN   TestDiffieHellmanKeyExchange/Test_2:_Key_Exchange\n--- FAIL: TestDiffieHellmanKeyExchange/Test_2:_Key_Exchange (0.00s)\n',
#     'details': '=== RUN   TestDiffieHellmanKeyExchange/Test_2:_Key_Exchange\n--- FAIL: TestDiffieHellmanKeyExchange/Test_2:_Key_Exchange (0.00s)\n'},
#    {'name': 'TestDSA',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/dsa',
#     'time': 0.03,
#     'status': 'passed',
#     'output': ['=== RUN   TestDSA\n', '--- PASS: TestDSA (0.03s)\n'],
#     'message': '=== RUN   TestDSA\n--- PASS: TestDSA (0.03s)\n',
#     'details': '=== RUN   TestDSA\n--- PASS: TestDSA (0.03s)\n'},
#    {'name': 'TestDSA/valid_signature',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/dsa',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDSA/valid_signature\n',
#      '--- PASS: TestDSA/valid_signature (0.00s)\n'],
#     'message': '=== RUN   TestDSA/valid_signature\n--- PASS: TestDSA/valid_signature (0.00s)\n',
#     'details': '=== RUN   TestDSA/valid_signature\n--- PASS: TestDSA/valid_signature (0.00s)\n'},
#    {'name': 'TestDSA/invalid_signature',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/dsa',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDSA/invalid_signature\n',
#      '--- PASS: TestDSA/invalid_signature (0.00s)\n'],
#     'message': '=== RUN   TestDSA/invalid_signature\n--- PASS: TestDSA/invalid_signature (0.00s)\n',
#     'details': '=== RUN   TestDSA/invalid_signature\n--- PASS: TestDSA/invalid_signature (0.00s)\n'},
#    {'name': 'TestNewPolybius',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestNewPolybius\n',
#      '=== PAUSE TestNewPolybius\n',
#      '=== CONT  TestNewPolybius\n',
#      '--- PASS: TestNewPolybius (0.00s)\n'],
#     'message': '=== RUN   TestNewPolybius\n=== PAUSE TestNewPolybius\n=== CONT  TestNewPolybius\n--- PASS: TestNewPolybius (0.00s)\n',
#     'details': '=== RUN   TestNewPolybius\n=== PAUSE TestNewPolybius\n=== CONT  TestNewPolybius\n--- PASS: TestNewPolybius (0.00s)\n'},
#    {'name': 'TestPolybiusEncrypt',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPolybiusEncrypt\n',
#      '=== PAUSE TestPolybiusEncrypt\n',
#      '=== CONT  TestPolybiusEncrypt\n',
#      '--- PASS: TestPolybiusEncrypt (0.00s)\n'],
#     'message': '=== RUN   TestPolybiusEncrypt\n=== PAUSE TestPolybiusEncrypt\n=== CONT  TestPolybiusEncrypt\n--- PASS: TestPolybiusEncrypt (0.00s)\n',
#     'details': '=== RUN   TestPolybiusEncrypt\n=== PAUSE TestPolybiusEncrypt\n=== CONT  TestPolybiusEncrypt\n--- PASS: TestPolybiusEncrypt (0.00s)\n'},
#    {'name': 'TestPolybiusDecrypt',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPolybiusDecrypt\n',
#      '=== PAUSE TestPolybiusDecrypt\n',
#      '=== CONT  TestPolybiusDecrypt\n',
#      '--- PASS: TestPolybiusDecrypt (0.00s)\n'],
#     'message': '=== RUN   TestPolybiusDecrypt\n=== PAUSE TestPolybiusDecrypt\n=== CONT  TestPolybiusDecrypt\n--- PASS: TestPolybiusDecrypt (0.00s)\n',
#     'details': '=== RUN   TestPolybiusDecrypt\n=== PAUSE TestPolybiusDecrypt\n=== CONT  TestPolybiusDecrypt\n--- PASS: TestPolybiusDecrypt (0.00s)\n'},
#    {'name': 'TestNewPolybius/correct_initialization',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestNewPolybius/correct_initialization\n',
#      '--- PASS: TestNewPolybius/correct_initialization (0.00s)\n'],
#     'message': '=== RUN   TestNewPolybius/correct_initialization\n--- PASS: TestNewPolybius/correct_initialization (0.00s)\n',
#     'details': '=== RUN   TestNewPolybius/correct_initialization\n--- PASS: TestNewPolybius/correct_initialization (0.00s)\n'},
#    {'name': 'TestNewPolybius/truncate_characters',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestNewPolybius/truncate_characters\n',
#      '--- PASS: TestNewPolybius/truncate_characters (0.00s)\n'],
#     'message': '=== RUN   TestNewPolybius/truncate_characters\n--- PASS: TestNewPolybius/truncate_characters (0.00s)\n',
#     'details': '=== RUN   TestNewPolybius/truncate_characters\n--- PASS: TestNewPolybius/truncate_characters (0.00s)\n'},
#    {'name': 'TestNewPolybius/invalid_key',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestNewPolybius/invalid_key\n',
#      '--- PASS: TestNewPolybius/invalid_key (0.00s)\n'],
#     'message': '=== RUN   TestNewPolybius/invalid_key\n--- PASS: TestNewPolybius/invalid_key (0.00s)\n',
#     'details': '=== RUN   TestNewPolybius/invalid_key\n--- PASS: TestNewPolybius/invalid_key (0.00s)\n'},
#    {'name': 'TestNewPolybius/invalid_characters',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestNewPolybius/invalid_characters\n',
#      '--- PASS: TestNewPolybius/invalid_characters (0.00s)\n'],
#     'message': '=== RUN   TestNewPolybius/invalid_characters\n--- PASS: TestNewPolybius/invalid_characters (0.00s)\n',
#     'details': '=== RUN   TestNewPolybius/invalid_characters\n--- PASS: TestNewPolybius/invalid_characters (0.00s)\n'},
#    {'name': 'TestPolybiusDecrypt/correct_decryption',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPolybiusDecrypt/correct_decryption\n',
#      '--- PASS: TestPolybiusDecrypt/correct_decryption (0.00s)\n'],
#     'message': '=== RUN   TestPolybiusDecrypt/correct_decryption\n--- PASS: TestPolybiusDecrypt/correct_decryption (0.00s)\n',
#     'details': '=== RUN   TestPolybiusDecrypt/correct_decryption\n--- PASS: TestPolybiusDecrypt/correct_decryption (0.00s)\n'},
#    {'name': 'TestPolybiusDecrypt/invalid_decryption(position_of_even_number)',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPolybiusDecrypt/invalid_decryption(position_of_even_number)\n',
#      '--- PASS: TestPolybiusDecrypt/invalid_decryption(position_of_even_number) (0.00s)\n'],
#     'message': '=== RUN   TestPolybiusDecrypt/invalid_decryption(position_of_even_number)\n--- PASS: TestPolybiusDecrypt/invalid_decryption(position_of_even_number) (0.00s)\n',
#     'details': '=== RUN   TestPolybiusDecrypt/invalid_decryption(position_of_even_number)\n--- PASS: TestPolybiusDecrypt/invalid_decryption(position_of_even_number) (0.00s)\n'},
#    {'name': 'TestPolybiusDecrypt/invalid_decryption(position_of_odd_number)',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPolybiusDecrypt/invalid_decryption(position_of_odd_number)\n',
#      '--- PASS: TestPolybiusDecrypt/invalid_decryption(position_of_odd_number) (0.00s)\n'],
#     'message': '=== RUN   TestPolybiusDecrypt/invalid_decryption(position_of_odd_number)\n--- PASS: TestPolybiusDecrypt/invalid_decryption(position_of_odd_number) (0.00s)\n',
#     'details': '=== RUN   TestPolybiusDecrypt/invalid_decryption(position_of_odd_number)\n--- PASS: TestPolybiusDecrypt/invalid_decryption(position_of_odd_number) (0.00s)\n'},
#    {'name': 'TestPolybiusDecrypt/invalid_text_size_which_is_odd',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPolybiusDecrypt/invalid_text_size_which_is_odd\n',
#      '--- PASS: TestPolybiusDecrypt/invalid_text_size_which_is_odd (0.00s)\n'],
#     'message': '=== RUN   TestPolybiusDecrypt/invalid_text_size_which_is_odd\n--- PASS: TestPolybiusDecrypt/invalid_text_size_which_is_odd (0.00s)\n',
#     'details': '=== RUN   TestPolybiusDecrypt/invalid_text_size_which_is_odd\n--- PASS: TestPolybiusDecrypt/invalid_text_size_which_is_odd (0.00s)\n'},
#    {'name': 'TestPolybiusEncrypt/correct_encryption',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPolybiusEncrypt/correct_encryption\n',
#      '--- PASS: TestPolybiusEncrypt/correct_encryption (0.00s)\n'],
#     'message': '=== RUN   TestPolybiusEncrypt/correct_encryption\n--- PASS: TestPolybiusEncrypt/correct_encryption (0.00s)\n',
#     'details': '=== RUN   TestPolybiusEncrypt/correct_encryption\n--- PASS: TestPolybiusEncrypt/correct_encryption (0.00s)\n'},
#    {'name': 'TestPolybiusEncrypt/invalid_encryption',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPolybiusEncrypt/invalid_encryption\n',
#      '--- PASS: TestPolybiusEncrypt/invalid_encryption (0.00s)\n'],
#     'message': '=== RUN   TestPolybiusEncrypt/invalid_encryption\n--- PASS: TestPolybiusEncrypt/invalid_encryption (0.00s)\n',
#     'details': '=== RUN   TestPolybiusEncrypt/invalid_encryption\n--- PASS: TestPolybiusEncrypt/invalid_encryption (0.00s)\n'},
#    {'name': 'FuzzPolybius',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   FuzzPolybius\n', '--- PASS: FuzzPolybius (0.00s)\n'],
#     'message': '=== RUN   FuzzPolybius\n--- PASS: FuzzPolybius (0.00s)\n',
#     'details': '=== RUN   FuzzPolybius\n--- PASS: FuzzPolybius (0.00s)\n'},
#    {'name': 'FuzzPolybius/seed#0',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   FuzzPolybius/seed#0\n',
#      '--- PASS: FuzzPolybius/seed#0 (0.00s)\n'],
#     'message': '=== RUN   FuzzPolybius/seed#0\n--- PASS: FuzzPolybius/seed#0 (0.00s)\n',
#     'details': '=== RUN   FuzzPolybius/seed#0\n--- PASS: FuzzPolybius/seed#0 (0.00s)\n'},
#    {'name': 'ExampleNewPolybius',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   ExampleNewPolybius\n',
#      '--- PASS: ExampleNewPolybius (0.00s)\n'],
#     'message': '=== RUN   ExampleNewPolybius\n--- PASS: ExampleNewPolybius (0.00s)\n',
#     'details': '=== RUN   ExampleNewPolybius\n--- PASS: ExampleNewPolybius (0.00s)\n'},
#    {'name': 'TestEncrypt',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt\n', '--- PASS: TestEncrypt (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt\n--- PASS: TestEncrypt (0.00s)\n',
#     'details': '=== RUN   TestEncrypt\n--- PASS: TestEncrypt (0.00s)\n'},
#    {'name': 'TestEncrypt/Encrypt_with_2_rails',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_with_2_rails\n',
#      '--- PASS: TestEncrypt/Encrypt_with_2_rails (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_with_2_rails\n--- PASS: TestEncrypt/Encrypt_with_2_rails (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_with_2_rails\n--- PASS: TestEncrypt/Encrypt_with_2_rails (0.00s)\n'},
#    {'name': 'TestEncrypt/Encrypt_with_3_rails',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_with_3_rails\n',
#      '--- PASS: TestEncrypt/Encrypt_with_3_rails (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_with_3_rails\n--- PASS: TestEncrypt/Encrypt_with_3_rails (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_with_3_rails\n--- PASS: TestEncrypt/Encrypt_with_3_rails (0.00s)\n'},
#    {'name': 'TestEncrypt/Encrypt_with_edge_case:_1_rail',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_with_edge_case:_1_rail\n',
#      '--- PASS: TestEncrypt/Encrypt_with_edge_case:_1_rail (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_with_edge_case:_1_rail\n--- PASS: TestEncrypt/Encrypt_with_edge_case:_1_rail (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_with_edge_case:_1_rail\n--- PASS: TestEncrypt/Encrypt_with_edge_case:_1_rail (0.00s)\n'},
#    {'name': 'TestEncrypt/Encrypt_with_more_rails_than_letters',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestEncrypt/Encrypt_with_more_rails_than_letters\n',
#      '--- PASS: TestEncrypt/Encrypt_with_more_rails_than_letters (0.00s)\n'],
#     'message': '=== RUN   TestEncrypt/Encrypt_with_more_rails_than_letters\n--- PASS: TestEncrypt/Encrypt_with_more_rails_than_letters (0.00s)\n',
#     'details': '=== RUN   TestEncrypt/Encrypt_with_more_rails_than_letters\n--- PASS: TestEncrypt/Encrypt_with_more_rails_than_letters (0.00s)\n'},
#    {'name': 'TestDecrypt',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt\n', '--- PASS: TestDecrypt (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt\n--- PASS: TestDecrypt (0.00s)\n',
#     'details': '=== RUN   TestDecrypt\n--- PASS: TestDecrypt (0.00s)\n'},
#    {'name': 'TestDecrypt/Decrypt_with_2_rails',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/Decrypt_with_2_rails\n',
#      '--- PASS: TestDecrypt/Decrypt_with_2_rails (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/Decrypt_with_2_rails\n--- PASS: TestDecrypt/Decrypt_with_2_rails (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/Decrypt_with_2_rails\n--- PASS: TestDecrypt/Decrypt_with_2_rails (0.00s)\n'},
#    {'name': 'TestDecrypt/Decrypt_with_3_rails',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/Decrypt_with_3_rails\n',
#      '--- PASS: TestDecrypt/Decrypt_with_3_rails (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/Decrypt_with_3_rails\n--- PASS: TestDecrypt/Decrypt_with_3_rails (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/Decrypt_with_3_rails\n--- PASS: TestDecrypt/Decrypt_with_3_rails (0.00s)\n'},
#    {'name': 'TestDecrypt/Decrypt_with_edge_case:_1_rail',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/Decrypt_with_edge_case:_1_rail\n',
#      '--- PASS: TestDecrypt/Decrypt_with_edge_case:_1_rail (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/Decrypt_with_edge_case:_1_rail\n--- PASS: TestDecrypt/Decrypt_with_edge_case:_1_rail (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/Decrypt_with_edge_case:_1_rail\n--- PASS: TestDecrypt/Decrypt_with_edge_case:_1_rail (0.00s)\n'},
#    {'name': 'TestDecrypt/Decrypt_with_more_rails_than_letters',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestDecrypt/Decrypt_with_more_rails_than_letters\n',
#      '--- PASS: TestDecrypt/Decrypt_with_more_rails_than_letters (0.00s)\n'],
#     'message': '=== RUN   TestDecrypt/Decrypt_with_more_rails_than_letters\n--- PASS: TestDecrypt/Decrypt_with_more_rails_than_letters (0.00s)\n',
#     'details': '=== RUN   TestDecrypt/Decrypt_with_more_rails_than_letters\n--- PASS: TestDecrypt/Decrypt_with_more_rails_than_letters (0.00s)\n'},
#    {'name': 'TestRot13Encrypt',
#     'classname': 'github.com/TheAlgorithms/Go/cipher/rot13',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestRot13Encrypt\n',
#      '--- PASS: TestRot13Encrypt (0.00s)\n'],
#     'message': '=== RUN   TestRot13Encrypt\n--- PASS: TestRot13Encrypt (0.00s)\n',
#     'details': '=== RUN   TestRot13Encrypt\n--- PASS: TestRot13Encrypt (0.00s)\n'},
#    {'name': "TestRot13Encrypt/Basic_rotation_with_letter_'a'_gives_'n",
#     'classname': 'github.com/TheAlgorithms/Go/cipher/rot13',
#     'time': 0,
#     'status': 'passed',
#     'output': ["=== RUN   TestRot13Encrypt/Basic_rotation_with_letter_'a'_gives_'n\n",
#      "--- PASS: TestRot13Encrypt/Basic_rotation_with_letter_'a'_gives_'n (0.00s)\n"],
#     'message': "=== RUN   TestRot13Encrypt/Basic_rotation_with_letter_'a'_gives_'n\n--- PASS: TestRot13Encrypt/Basic_rotation_with_letter_'a'_gives_'n (0.00s)\n",
#     'details': "=== RUN   TestRot13Encrypt/Basic_rotation_with_letter_'a'_gives_'n\n--- PASS: TestRot13Encrypt/Basic_rotation_with_letter_'a'_gives_'n (0.00s)\n"},
#    {'name': "TestRot13Encrypt/Rotation_with_wrapping_around_alphabet_on_letter_'z'_gives_'m'",
#     'classname': 'github.com/TheAlgorithms/Go/cipher/rot13',
#     'time': 0,
#     'status': 'passed',
#     'output': ["=== RUN   TestRot13Encrypt/Rotation_with_wrapping_around_alphabet_on_letter_'z'_gives_'m'\n",
#      "--- PASS: TestRot13Encrypt/Rotation_with_wrapping_around_alphabet_on_letter_'z'_gives_'m' (0.00s)\n"],
#     'message': "=== RUN   TestRot13Encrypt/Rotation_with_wrapping_around_alphabet_on_letter_'z'_gives_'m'\n--- PASS: TestRot13Encrypt/Rotation_with_wrapping_around_alphabet_on_letter_'z'_gives_'m' (0.00s)\n",
# ...
#    {'name': 'TestPronicNumber/358_is_not_pronic',
#     'classname': 'github.com/TheAlgorithms/Go/math',
#     'time': 0,
#     'status': 'passed',
#     'output': ['=== RUN   TestPronicNumber/358_is_not_pronic\n',
#      '--- PASS: TestPronicNumber/358_is_not_pronic (0.00s)\n'],
#     'message': '=== RUN   TestPronicNumber/358_is_not_pronic\n--- PASS: TestPronicNumber/358_is_not_pronic (0.00s)\n',
#     'details': '=== RUN   TestPronicNumber/358_is_not_pronic\n--- PASS: TestPronicNumber/358_is_not_pronic (0.00s)\n'},
#    ...],
#   'summary': {'total': 2636,
#    'passed': 2633,
#    'failed': 2,
#    'skipped': 1,
#    'errors': 0,
#    'collected': 2636},
#   'packages': {'github.com/TheAlgorithms/Go/cache': {'name': 'github.com/TheAlgorithms/Go/cache',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/checksum': {'name': 'github.com/TheAlgorithms/Go/checksum',
#     'status': 'passed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/cipher': {'name': 'github.com/TheAlgorithms/Go/cipher',
#     'status': 'passed',
#     'elapsed': 0.001},
#    'github.com/TheAlgorithms/Go/cipher/caesar': {'name': 'github.com/TheAlgorithms/Go/cipher/caesar',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/cipher/diffiehellman': {'name': 'github.com/TheAlgorithms/Go/cipher/diffiehellman',
#     'status': 'failed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/cipher/dsa': {'name': 'github.com/TheAlgorithms/Go/cipher/dsa',
#     'status': 'passed',
#     'elapsed': 0.033},
#    'github.com/TheAlgorithms/Go/cipher/polybius': {'name': 'github.com/TheAlgorithms/Go/cipher/polybius',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/cipher/railfence': {'name': 'github.com/TheAlgorithms/Go/cipher/railfence',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/cipher/rot13': {'name': 'github.com/TheAlgorithms/Go/cipher/rot13',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/cipher/rsa': {'name': 'github.com/TheAlgorithms/Go/cipher/rsa',
#     'status': 'passed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/cipher/transposition': {'name': 'github.com/TheAlgorithms/Go/cipher/transposition',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/cipher/xor': {'name': 'github.com/TheAlgorithms/Go/cipher/xor',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/compression': {'name': 'github.com/TheAlgorithms/Go/compression',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/constraints': {'name': 'github.com/TheAlgorithms/Go/constraints',
#     'status': 'skipped',
#     'elapsed': 0},
#    'github.com/TheAlgorithms/Go/conversion': {'name': 'github.com/TheAlgorithms/Go/conversion',
#     'status': 'passed',
#     'elapsed': 0.009},
#    'github.com/TheAlgorithms/Go/dynamic': {'name': 'github.com/TheAlgorithms/Go/dynamic',
#     'status': 'passed',
#     'elapsed': 0.029},
#    'github.com/TheAlgorithms/Go/graph': {'name': 'github.com/TheAlgorithms/Go/graph',
#     'status': 'passed',
#     'elapsed': 0.87},
#    'github.com/TheAlgorithms/Go/graph/coloring': {'name': 'github.com/TheAlgorithms/Go/graph/coloring',
#     'status': 'passed',
#     'elapsed': 0.007},
#    'github.com/TheAlgorithms/Go/hashing': {'name': 'github.com/TheAlgorithms/Go/hashing',
#     'status': 'passed',
#     'elapsed': 0.001},
#    'github.com/TheAlgorithms/Go/hashing/md5': {'name': 'github.com/TheAlgorithms/Go/hashing/md5',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/hashing/sha1': {'name': 'github.com/TheAlgorithms/Go/hashing/sha1',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/hashing/sha256': {'name': 'github.com/TheAlgorithms/Go/hashing/sha256',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/math': {'name': 'github.com/TheAlgorithms/Go/math',
#     'status': 'passed',
#     'elapsed': 0.075},
#    'github.com/TheAlgorithms/Go/math/armstrong': {'name': 'github.com/TheAlgorithms/Go/math/armstrong',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/math/binary': {'name': 'github.com/TheAlgorithms/Go/math/binary',
#     'status': 'passed',
#     'elapsed': 0.017},
#    'github.com/TheAlgorithms/Go/math/catalan': {'name': 'github.com/TheAlgorithms/Go/math/catalan',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/math/factorial': {'name': 'github.com/TheAlgorithms/Go/math/factorial',
#     'status': 'passed',
#     'elapsed': 0.007},
#    'github.com/TheAlgorithms/Go/math/fibonacci': {'name': 'github.com/TheAlgorithms/Go/math/fibonacci',
#     'status': 'passed',
#     'elapsed': 0.008},
#    'github.com/TheAlgorithms/Go/math/gcd': {'name': 'github.com/TheAlgorithms/Go/math/gcd',
#     'status': 'passed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/math/geometry': {'name': 'github.com/TheAlgorithms/Go/math/geometry',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/math/lcm': {'name': 'github.com/TheAlgorithms/Go/math/lcm',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/math/matrix': {'name': 'github.com/TheAlgorithms/Go/math/matrix',
#     'status': 'passed',
#     'elapsed': 0.082},
#    'github.com/TheAlgorithms/Go/math/max': {'name': 'github.com/TheAlgorithms/Go/math/max',
#     'status': 'passed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/math/min': {'name': 'github.com/TheAlgorithms/Go/math/min',
#     'status': 'passed',
#     'elapsed': 0.006},
#    'github.com/TheAlgorithms/Go/math/modular': {'name': 'github.com/TheAlgorithms/Go/math/modular',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/math/moserdebruijnsequence': {'name': 'github.com/TheAlgorithms/Go/math/moserdebruijnsequence',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/math/pascal': {'name': 'github.com/TheAlgorithms/Go/math/pascal',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/math/permutation': {'name': 'github.com/TheAlgorithms/Go/math/permutation',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/math/pi': {'name': 'github.com/TheAlgorithms/Go/math/pi',
#     'status': 'passed',
#     'elapsed': 0.814},
#    'github.com/TheAlgorithms/Go/math/power': {'name': 'github.com/TheAlgorithms/Go/math/power',
#     'status': 'passed',
#     'elapsed': 0.006},
#    'github.com/TheAlgorithms/Go/math/prime': {'name': 'github.com/TheAlgorithms/Go/math/prime',
#     'status': 'passed',
#     'elapsed': 0.074},
#    'github.com/TheAlgorithms/Go/math/pythagoras': {'name': 'github.com/TheAlgorithms/Go/math/pythagoras',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/other': {'name': 'github.com/TheAlgorithms/Go/other',
#     'status': 'passed',
#     'elapsed': 0.001},
#    'github.com/TheAlgorithms/Go/other/maxsubarraysum': {'name': 'github.com/TheAlgorithms/Go/other/maxsubarraysum',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/other/nested': {'name': 'github.com/TheAlgorithms/Go/other/nested',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/other/password': {'name': 'github.com/TheAlgorithms/Go/other/password',
#     'status': 'skipped',
#     'elapsed': 0},
#    'github.com/TheAlgorithms/Go/project_euler/problem_1': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_1',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_10': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_10',
#     'status': 'passed',
#     'elapsed': 0.016},
#    'github.com/TheAlgorithms/Go/project_euler/problem_11': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_11',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_12': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_12',
#     'status': 'passed',
#     'elapsed': 0.038},
#    'github.com/TheAlgorithms/Go/project_euler/problem_13': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_13',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/project_euler/problem_14': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_14',
#     'status': 'passed',
#     'elapsed': 0.228},
#    'github.com/TheAlgorithms/Go/project_euler/problem_15': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_15',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_16': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_16',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_17': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_17',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_18': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_18',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/project_euler/problem_19': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_19',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_2': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_2',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_20': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_20',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_3': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_3',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_4': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_4',
#     'status': 'passed',
#     'elapsed': 29.991},
#    'github.com/TheAlgorithms/Go/project_euler/problem_5': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_5',
#     'status': 'passed',
#     'elapsed': 0.37},
#    'github.com/TheAlgorithms/Go/project_euler/problem_6': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_6',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/project_euler/problem_7': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_7',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/project_euler/problem_8': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_8',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/project_euler/problem_9': {'name': 'github.com/TheAlgorithms/Go/project_euler/problem_9',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/search': {'name': 'github.com/TheAlgorithms/Go/search',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/sort': {'name': 'github.com/TheAlgorithms/Go/sort',
#     'status': 'passed',
#     'elapsed': 0.037},
#    'github.com/TheAlgorithms/Go/sqrt': {'name': 'github.com/TheAlgorithms/Go/sqrt',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/strings': {'name': 'github.com/TheAlgorithms/Go/strings',
#     'status': 'passed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/strings/ahocorasick': {'name': 'github.com/TheAlgorithms/Go/strings/ahocorasick',
#     'status': 'passed',
#     'elapsed': 0.008},
#    'github.com/TheAlgorithms/Go/strings/bom': {'name': 'github.com/TheAlgorithms/Go/strings/bom',
#     'status': 'skipped',
#     'elapsed': 0},
#    'github.com/TheAlgorithms/Go/strings/combination': {'name': 'github.com/TheAlgorithms/Go/strings/combination',
#     'status': 'skipped',
#     'elapsed': 0},
#    'github.com/TheAlgorithms/Go/strings/generateparentheses': {'name': 'github.com/TheAlgorithms/Go/strings/generateparentheses',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/strings/genetic': {'name': 'github.com/TheAlgorithms/Go/strings/genetic',
#     'status': 'passed',
#     'elapsed': 0.073},
#    'github.com/TheAlgorithms/Go/strings/guid': {'name': 'github.com/TheAlgorithms/Go/strings/guid',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/strings/hamming': {'name': 'github.com/TheAlgorithms/Go/strings/hamming',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/strings/horspool': {'name': 'github.com/TheAlgorithms/Go/strings/horspool',
#     'status': 'passed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/strings/kmp': {'name': 'github.com/TheAlgorithms/Go/strings/kmp',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/strings/levenshtein': {'name': 'github.com/TheAlgorithms/Go/strings/levenshtein',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/strings/manacher': {'name': 'github.com/TheAlgorithms/Go/strings/manacher',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/strings/palindrome': {'name': 'github.com/TheAlgorithms/Go/strings/palindrome',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/strings/pangram': {'name': 'github.com/TheAlgorithms/Go/strings/pangram',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/strings/parenthesis': {'name': 'github.com/TheAlgorithms/Go/strings/parenthesis',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/strings/search': {'name': 'github.com/TheAlgorithms/Go/strings/search',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/structure': {'name': 'github.com/TheAlgorithms/Go/structure',
#     'status': 'passed',
#     'elapsed': 0.001},
#    'github.com/TheAlgorithms/Go/structure/circularqueue': {'name': 'github.com/TheAlgorithms/Go/structure/circularqueue',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/structure/deque': {'name': 'github.com/TheAlgorithms/Go/structure/deque',
#     'status': 'passed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/structure/dynamicarray': {'name': 'github.com/TheAlgorithms/Go/structure/dynamicarray',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/structure/fenwicktree': {'name': 'github.com/TheAlgorithms/Go/structure/fenwicktree',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/structure/hashmap': {'name': 'github.com/TheAlgorithms/Go/structure/hashmap',
#     'status': 'passed',
#     'elapsed': 0.003},
#    'github.com/TheAlgorithms/Go/structure/heap': {'name': 'github.com/TheAlgorithms/Go/structure/heap',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/structure/linkedlist': {'name': 'github.com/TheAlgorithms/Go/structure/linkedlist',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/structure/queue': {'name': 'github.com/TheAlgorithms/Go/structure/queue',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/structure/segmenttree': {'name': 'github.com/TheAlgorithms/Go/structure/segmenttree',
#     'status': 'passed',
#     'elapsed': 0.002},
#    'github.com/TheAlgorithms/Go/structure/set': {'name': 'github.com/TheAlgorithms/Go/structure/set',
#     'status': 'passed',
#     'elapsed': 0.005},
#    'github.com/TheAlgorithms/Go/structure/stack': {'name': 'github.com/TheAlgorithms/Go/structure/stack',
#     'status': 'passed',
#     'elapsed': 0.004},
#    'github.com/TheAlgorithms/Go/structure/tree': {'name': 'github.com/TheAlgorithms/Go/structure/tree',
#     'status': 'passed',
#     'elapsed': 3.005},
#    'github.com/TheAlgorithms/Go/structure/trie': {'name': 'github.com/TheAlgorithms/Go/structure/trie',
#     'status': 'passed',
#     'elapsed': 0.005}},
#   'status': 'failed'},
#  'time': 46.99515628814697,
#  'run_id': '27f520ab'}
